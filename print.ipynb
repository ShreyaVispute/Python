# %%
print("Hello World")
# Out:
# Hello World

# %%
print(6)
# Out:
# 6

# %%
# by default sep=" "
print("India","Pakisthan","Shrilanka","Japan")
# Out:
# India Pakisthan Shrilanka Japan

# %%
print("India","Pakisthan","Shrilanka","Japan",sep="/")
# Out:
# India/Pakisthan/Shrilanka/Japan

# %%
print("India","Pakisthan","Shrilanka","Japan",sep="-")
# Out:
# India-Pakisthan-Shrilanka-Japan

# %%
# by default end=/n
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello", end=" ")
print("World")
# Out:
# Hello World
